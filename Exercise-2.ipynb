# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(url, sep = "\t")

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top_5 = chipo.groupby("item_name")["quantity"].sum().sort_values(ascending=False).head(5)
filtered = chipo[chipo["item_name"].isin(top_5.index)]
plt.hist(filtered["item_name"], bins=5)
# Out:
# (array([726., 368., 479., 553., 301.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
plt.scatter(chipo.groupby("item_price")["quantity"].sum().index, chipo.groupby("item_price")["quantity"].sum().values)

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.

# %%
#create a pie chart to show the top 10 items ordered

top_ten = chipo.groupby("item_name")["quantity"].sum().sort_values(ascending=False).head(10)
plt.pie(top_ten, labels=top_ten.index, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1666cb71900>,
# ...
#  [Text(0.8549534231188284, 0.6921377350624641, 'Chicken Bowl'),
#   Text(-0.34477985204405426, 1.0445701764958064, 'Chicken Burrito'),
#   Text(-1.0598641334180172, 0.2944282912596474, 'Chips and Guacamole'),
#   Text(-0.9509018166941017, -0.5529789643448088, 'Steak Burrito'),
#   Text(-0.4131007699557631, -1.0194840625835973, 'Canned Soft Drink'),
#   Text(0.1476008346289448, -1.0900522893957147, 'Chips'),
#   Text(0.5635737797779576, -0.9446611004729614, 'Steak Bowl'),
#   Text(0.8779758047508922, -0.6626903396549728, 'Bottled Water'),
#   Text(1.0364368531311885, -0.3685086830340901, 'Chips and Fresh Tomato Salsa'),
#   Text(1.0930242955417702, -0.12368463669921738, 'Canned Soda')],
#  [Text(0.46633823079208814, 0.37752967367043494, '21.7%'),
#   Text(-0.18806173747857502, 0.5697655508158944, '16.8%'),
#   Text(-0.5781077091371002, 0.1605972497779895, '14.4%'),
#   Text(-0.5186737181967827, -0.30162488964262296, '11.0%'),
# ...
